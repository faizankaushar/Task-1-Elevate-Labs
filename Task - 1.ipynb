# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv("sales_data_sample.csv",encoding="latin1")

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # Looking top 5 values of the dataset

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %% [markdown]
# # Checking information of the dataset by using info() function like null values etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # Checking for statistical information of the dataset

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %% [markdown]
# # Checking for null values in each rows

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# # Checking total number of null values in the dataset

# %%
df.isnull().sum().sum()
# Out:
# 5157

# %% [markdown]
# # Getting all the column names

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # Dropping the column 'ADDRESSLINE2' because it contains maximun null values

# %%
df.drop(columns='ADDRESSLINE2', inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # Checking null values in the column 'STATE'

# %%
df['STATE'].isnull().sum()
# Out:
# 1486

# %% [markdown]
# # Filling null values will forward filled values

# %%
df['STATE'].ffill(inplace=True)
# Out:
# C:\Users\HS\AppData\Local\Temp\ipykernel_8520\2346483568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['STATE'].ffill(inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # Getting total number of null values present in the column 'TERRITORY'

# %%
df['TERRITORY'].isnull().sum()
# Out:
# 1074

# %% [markdown]
# # Replacing all null values present in the column 'TERRITORY' with the backward values

# %%
df['TERRITORY'].bfill(inplace=True)
# Out:
# C:\Users\HS\AppData\Local\Temp\ipykernel_8520\4247915640.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TERRITORY'].bfill(inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['TERRITORY'].isnull().sum()
# Out:
# 1

# %%
df['TERRITORY'].ffill(inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # Checking again if there is null values in the dataset

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER          0
# QUANTITYORDERED      0
# PRICEEACH            0
# ORDERLINENUMBER      0
# SALES                0
# ORDERDATE            0
# STATUS               0
# QTR_ID               0
# MONTH_ID             0
# YEAR_ID              0
# PRODUCTLINE          0
# MSRP                 0
# PRODUCTCODE          0
# CUSTOMERNAME         0
# PHONE                0
# ADDRESSLINE1         0
# CITY                 0
# STATE                0
# POSTALCODE          76
# COUNTRY              0
# TERRITORY            0
# CONTACTLASTNAME      0
# CONTACTFIRSTNAME     0
# DEALSIZE             0
# dtype: int64

# %% [markdown]
# # Getting total number of null values present in the column 'POSTALCODE'

# %%
df['POSTALCODE'].isnull().sum()
# Out:
# 76

# %% [markdown]
# # Replacing all the null values present in the 'POSTALCODE' with forward values

# %%
df['POSTALCODE'].fillna(0,inplace=True)
# Out:
# C:\Users\HS\AppData\Local\Temp\ipykernel_8520\2187132722.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['POSTALCODE'].fillna(0,inplace=True)

# %% [markdown]
# # Again checking if there is any null values remaining in the dataset

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %% [markdown]
# # Renaming the names of the columns in the dataset

# %%
df.rename(columns={'ORDERNUMBER':'ORDER_NUMBER',
                   'QUANTITYORDERED':'QUANTITY_ORDERED',
                   'PRICEEACH':'PRICE_EACH',
                   'ORDERLINENUMBER':'ORDER_LINENUMBER',
                   'ORDERDATE':'ORDER_DATE',
                  }, inplace=True)

# %%
df.columns
# Out:
# Index(['ORDER_NUMBER', 'QUANTITY_ORDERED', 'PRICE_EACH', 'ORDER_LINENUMBER',
#        'SALES', 'ORDER_DATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # Checking if there is any duplicate values / records present in the dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINENUMBER    SALES  \
# 0         10107                30       95.70                 2  2871.00
# 1         10121                34       81.35                 5  2765.90
# 2         10134                41       94.74                 2  3884.34
# 3         10145                45       83.26                 6  3746.70
# 4         10159                49      100.00                14  5205.27
#
#         ORDER_DATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...        6505551386
#
# ...

# %% [markdown]
# # Checking the data type of the column 'ORDER_DATE'

# %%
df['ORDER_DATE'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Changing the data type of the column 'ORDER_DATE' from date time to date

# %%
df['ORDER_DATE']=pd.to_datetime(df['ORDER_DATE']).dt.normalize()

# %% [markdown]
# # Again checking the data type of the column 'ORDER_DATE'

# %%
df['ORDER_DATE'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df
# Out:
#       ORDER_NUMBER  QUANTITY_ORDERED  PRICE_EACH  ORDER_LINENUMBER    SALES  \
# 0            10107                30       95.70                 2  2871.00
# 1            10121                34       81.35                 5  2765.90
# 2            10134                41       94.74                 2  3884.34
# 3            10145                45       83.26                 6  3746.70
# 4            10159                49      100.00                14  5205.27
# ...            ...               ...         ...               ...      ...
# 2818         10350                20      100.00                15  2244.40
# 2819         10373                29      100.00                 1  3978.51
# 2820         10386                43      100.00                 4  5417.57
# 2821         10397                34       62.24                 1  2116.16
# 2822         10414                47       65.52                 9  3079.44
#
# ...
